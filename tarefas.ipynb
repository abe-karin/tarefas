# %%
# %pip install pandas
# %pip install openpyxl
# %pip install matplotlib
import pandas as pd

# Carregar os dados
df = pd.read_excel('arquivo.xlsx')
# Ver as primeiras linhas
df.head()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
#         Data     Matéria      Tipo     Status Nota  Tempo_Gasto (min)
# 0 2025-01-03  Matemática     Prova  Concluído    7                200
# 1 2025-11-22   Português     Lição  Concluído    8                210
# 2 2025-06-08    Ciências  Trabalho   Pendente    -                  0
# 3 2025-03-17    História     Lição   Pendente    -                  0
# 4 2025-10-29   Geografia  Trabalho  Concluído    9                300

# %%
# Preenche notas vazias com 0
df['Nota'] = df['Nota'].fillna(0)

# %%
# Soma o tempo gasto por matéria (nome correto da coluna)
tempo_por_materia = df.groupby('Matéria')['Tempo_Gasto (min)'].sum()
print(tempo_por_materia)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Soma o tempo gasto por matéria
# ----> 2 tempo_por_materia = df.groupby('Matéria')['Tempo_Gasto'].sum()
#       3 print(tempo_por_materia)
#
# File ~/Documentos/github/tarefas/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# ...

# %%
import matplotlib.pyplot as plt

tempo_por_materia.plot(kind='bar', color='skyblue')
plt.title('Tempo Total de Estudo por Matéria')
plt.ylabel('Minutos')
plt.show()
